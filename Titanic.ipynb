# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import math

# %%
train_df=pd.read_csv('/Users/chaitanyakrishna/Desktop/titanic (1)/train.csv')
test_df=pd.read_csv('/Users/chaitanyakrishna/Desktop/titanic (1)/test.csv')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df[train_df['Age'].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df['Age'] = train_df.groupby(['Sex', 'Pclass'])['Age'].transform(lambda x: x.fillna(x.median()))

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df=train_df.drop(['PassengerId', 'Name', 'Ticket','Cabin'],axis=1)

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  21.5      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  21.5      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#      FamilySize
# 0             2
# 1             2
# 2             1
# 3             2
# 4             1
# ..          ...
# 886           1
# ...

# %%
train_df['IsAlone'] = (train_df['FamilySize'] == 1).astype(int)

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  21.5      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2        0
# 1             2        0
# 2             1        1
# 3             2        0
# ...

# %%
train_df['Embarked'] = train_df['Embarked'].fillna(train_df['Embarked'].mode()[0])

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  21.5      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2        0
# 1             2        0
# 2             1        1
# 3             2        0
# ...

# %%
train_df = pd.get_dummies(train_df, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
train_df[train_df.select_dtypes('bool').columns] = train_df.select_dtypes('bool').astype(int)

# %%
train_df
# Out:
#      Survived   Age  SibSp  Parch     Fare  FamilySize  IsAlone  Sex_male  \
# 0           0  22.0      1      0   7.2500           2        0         1
# 1           1  38.0      1      0  71.2833           2        0         0
# 2           1  26.0      0      0   7.9250           1        1         0
# 3           1  35.0      1      0  53.1000           2        0         0
# 4           0  35.0      0      0   8.0500           1        1         1
# ..        ...   ...    ...    ...      ...         ...      ...       ...
# 886         0  27.0      0      0  13.0000           1        1         1
# 887         1  19.0      0      0  30.0000           1        1         0
# 888         0  21.5      1      2  23.4500           4        0         0
# 889         1  26.0      0      0  30.0000           1        1         1
# 890         0  32.0      0      0   7.7500           1        1         1
#
#      Embarked_Q  Embarked_S  Pclass_2  Pclass_3
# ...

# %%
X=train_df.drop('Survived',axis=1).to_numpy()
y=train_df['Survived'].to_numpy().reshape(-1,1)

# %%
X
# Out:
# array([[22. ,  1. ,  0. , ...,  1. ,  0. ,  1. ],
#        [38. ,  1. ,  0. , ...,  0. ,  0. ,  0. ],
#        [26. ,  0. ,  0. , ...,  1. ,  0. ,  1. ],
#        ...,
#        [21.5,  1. ,  2. , ...,  1. ,  0. ,  1. ],
#        [26. ,  0. ,  0. , ...,  0. ,  0. ,  0. ],
#        [32. ,  0. ,  0. , ...,  0. ,  0. ,  1. ]])

# %%
# UNQ_C1
# GRADED FUNCTION: sigmoid

def sigmoid(z):

    g= 1/(1+np.exp(-z))
    
    return g

# %%
# UNQ_C2
# GRADED FUNCTION: compute_cost
def compute_cost(X, y, w, b, *argv):
    m, n = X.shape
    
    ### START CODE HERE ###
    total_cost=0
    
    for i in range(m):
        z=np.dot(X[i],w)+b
        f_wb=sigmoid(z)
        full= -y[i]*np.log(f_wb)-(1-y[i])*np.log(1-f_wb)
        total_cost=total_cost+full
    
    total_cost=total_cost/m

    return total_cost

# %%
# UNQ_C3
# GRADED FUNCTION: compute_gradient
def compute_gradient(X, y, w, b, *argv): 

    m, n = X.shape
    dj_dw = np.zeros(w.shape)
    dj_db = 0.

    ### START CODE HERE ### 
    for i in range(m):
        f_wb= sigmoid(np.dot(X[i],w)+b)
        value=f_wb-y[i]
        for j in range(n):
            dj_dw[j]=dj_dw[j]+value*X[i,j]
        dj_db=dj_db+value
      
            
    dj_dw = dj_dw/m
    dj_db = dj_db/m
    ### END CODE HERE ###

        
    return dj_db, dj_dw

# %%
def gradient_descent(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters, lambda_): 

    # number of training examples
    m = len(X)
    
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    w_history = []
    
    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_db, dj_dw = gradient_function(X, y, w_in, b_in, lambda_)   

        # Update Parameters using w, b, alpha and gradient
        w_in = w_in - alpha * dj_dw               
        b_in = b_in - alpha * dj_db              
       
        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            cost =  cost_function(X, y, w_in, b_in, lambda_)
            J_history.append(cost)

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters/10) == 0 or i == (num_iters-1):
            w_history.append(w_in)
            print(f"Iteration {i:4}: Cost {J_history[-1].item():8.2f}")
        
    return w_in, b_in, J_history, w_history #return w and J,w history for graphing

# %%
n = X.shape[1]
initial_w = 0.01 * (np.random.rand(n, 1) - 0.5)  # shape (11, 1)
initial_b = 0

# Some gradient descent settings
iterations = 4000
alpha = 0.003

w,b, J_history,_ = gradient_descent(X ,y, initial_w, initial_b, 
                                   compute_cost, compute_gradient, alpha, iterations, 0)
# Out:
# Iteration    0: Cost     0.65
# Iteration  400: Cost     0.60
# Iteration  800: Cost     0.58
# Iteration 1200: Cost     0.57
# Iteration 1600: Cost     0.56
# Iteration 2000: Cost     0.55
# Iteration 2400: Cost     0.54
# Iteration 2800: Cost     0.53
# Iteration 3200: Cost     0.53
# Iteration 3600: Cost     0.52
# Iteration 3999: Cost     0.52

# %%
def predict(X, w, b): 
    """
    Predict whether the label is 0 or 1 using learned logistic
    regression parameters w
    
    Args:
      X : (ndarray Shape (m,n)) data, m examples by n features
      w : (ndarray Shape (n,))  values of parameters of the model      
      b : (scalar)              value of bias parameter of the model

    Returns:
      p : (ndarray (m,)) The predictions for X using a threshold at 0.5
    """
    # number of training examples
    m, n = X.shape   
    p = np.zeros(m)
   
    ### START CODE HERE ### 
    # Loop over each example
    for i in range(m):   
        f_wb=sigmoid(np.dot(X[i],w)+b)


        
        if f_wb>=0.5:
            p[i]=1
        else:p[i]=0
    ### END CODE HERE ### 
    return p

# %%
p = predict(X, w,b)
print('Train Accuracy: %f'%(np.mean(p == y) * 100))
# Out:
# Train Accuracy: 56.453423
